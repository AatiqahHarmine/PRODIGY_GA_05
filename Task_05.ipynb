# %% [markdown]
# <a href="https://colab.research.google.com/github/AatiqahHarmine/PRODIGY_GA_05/blob/main/Task_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task - 05

# %% [markdown]
# Neural Style Transfer : Use a pre-trained deep learning model to blend the content of one image with the style of another.

# %% [markdown]
# Step - 01 :
#
# It opens a file chooser dialog in the Colab interface.
#
# You can select files (like your_content.jpg, your_style.jpg).
#
# After upload, the files are stored temporarily in the Colab environment.
#
# You can access them using their filenames like "your_content.jpg" in your code.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-671c03cd-4d44-4744-a8c4-722ffde5dc89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-671c03cd-4d44-4744-a8c4-722ffde5dc89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e640e505-34c5-45a4-bb60-d1c163c0a0cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e640e505-34c5-45a4-bb60-d1c163c0a0cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Step - 02:
#
# They call your load_image() function (defined earlier) and pass the filenames of your uploaded images.
#
# "2997 (1).jpg" is the content image (the image whose structure you want to keep).
#
# "AI_generated starry night (2).png" is the style image (the painting or artistic style you want to apply).

# %%
content_image = load_image("2997 (1).jpg")
style_image = load_image("AI_generated starry night (2).png")

# %% [markdown]
# Step - 03 Is used to install the required Python libraries for your neural style transfer project in environments like Google Colab.

# %%
# !pip install tensorflow tensorflow_hub

# %% [markdown]
# Step - 04 :
#
# These are essential libraries:
#
# tensorflow for deep learning operations
#
# tensorflow_hub to load the pre-trained model
#
# matplotlib for displaying the image
#
# PIL.Image and numpy for image handling (though PIL.Image isn’t used here)

# %% [markdown]
# def load_image(path):
#     img = tf.io.read_file(path)
#     img = tf.image.decode_image(img, channels=3)
#     img = tf.image.convert_image_dtype(img, tf.float32)
#     img = tf.image.resize(img, (512, 512))
#     return img[tf.newaxis, :]
#
# This function:
#
# Loads the image file (tf.io.read_file)
#
# Decodes it into an image tensor
#
# Converts it to float32 in [0,1] range
#
# Resizes it to 512x512
#
# Adds a batch dimension ([1, 512, 512, 3])

# %% [markdown]
# content_image = load_image("2997 (1).jpg")
# style_image = load_image("AI_generated starry night (2).png")
#
# These lines load:
#
# Your base image (content)
#
# Your style reference (e.g., painting)

# %% [markdown]
# hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
# stylized_image = hub_model(tf.constant(content_image), tf.constant(style_image))[0]
#
# This loads the pre-trained arbitrary image stylization model and runs the style transfer, outputting a stylized image tensor.

# %% [markdown]
# plt.figure(figsize=(10, 10))
# plt.imshow(tf.squeeze(stylized_image))
# plt.axis('off')
# plt.title("Stylized Image")
# plt.show()
#
# This removes the batch dimension, renders the image, and shows it without axes.

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import PIL.Image

def load_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, (512, 512))
    return img[tf.newaxis, :]

content_image = load_image("2997 (1).jpg")
style_image = load_image("AI_generated starry night (2).png")

hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

stylized_image = hub_model(tf.constant(content_image), tf.constant(style_image))[0]

plt.figure(figsize=(10, 10))
plt.imshow(tf.squeeze(stylized_image))
plt.axis('off')
plt.title("Stylized Image")
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-36ce2820-075b-4f45-9d02-a788bb39c672" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36ce2820-075b-4f45-9d02-a788bb39c672">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-551841ff-b176-4799-9cd5-ccb3b3508cf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-551841ff-b176-4799-9cd5-ccb3b3508cf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
content_image = load_image("download.jpeg")
style_image = load_image("30d60e82-7619-43ec-8c78-db547e29cd8d (1).jpg")

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import PIL.Image

def load_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, (512, 512))
    return img[tf.newaxis, :]

content_image = load_image("download.jpeg")
style_image = load_image("30d60e82-7619-43ec-8c78-db547e29cd8d (1).jpg")

hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

stylized_image = hub_model(tf.constant(content_image), tf.constant(style_image))[0]

plt.figure(figsize=(10, 10))
plt.imshow(tf.squeeze(stylized_image))
plt.axis('off')
plt.title("Stylized Image")
plt.show()
